# %% [markdown]
# **Description:** Install and configure Cursor AI. Use it to generate a Python function (e.g., sum of squares).
#
# **Expected Output:** Screenshots of working environments with few prompts to generate python code.

# %% [markdown]
# **Prerequisites:** Cursor AI Software, Internet Connection.

# %% [markdown]
# **Prompts and Screenshots:**

# %% [markdown]
# 1.	Write code for a function that can perform sum of squares upto n numbers in python
#
# ![image.png](attachment:image.png)
#
# 2.	Perform testing on the sum_of_squares() function from the attached Program.py file, and document the areas of improvement in the same function using comments
#
# ![image-2.png](attachment:image-2.png)
#
# 3.	Read the comments in the sum_of_squares() function in the attached Program.py file and implement the potential improvements mentioned
#
# ![image-3.png](attachment:image-3.png)
