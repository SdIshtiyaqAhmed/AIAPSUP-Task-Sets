# %% [markdown]
# **Description:** Provide a faulty class definition (missing self in parameters). Let AI fix it
# ```
# class Rectangle:
#   def __init__(length, width):
#     self.length = length
#     self.width = width
# ```
#
# **Expected Output:** Correct __init__() method and explanation

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** fix the code and explain the error fixed in the code using comments:
# ```
# class Rectangle:
#   def __init__(length, width):
#     self.length = length
#     self.width = width
# ```

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
class Rectangle:
  # The __init__ method needs 'self' as the first parameter
  def __init__(self, length, width):
    self.length = length
    self.width = width

# You can now create an instance of the Rectangle class like this:
my_rectangle = Rectangle(10, 5)
print(my_rectangle.length)
print(my_rectangle.width)
# Out:
# 10
# 5
