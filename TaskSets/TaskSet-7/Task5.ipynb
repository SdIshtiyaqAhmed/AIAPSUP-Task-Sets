# %% [markdown]
# **Description:** Access an invalid list index and use AI to resolve the Index Error.
# ```
# numbers = [1, 2, 3]
# print(numbers[5])
# ```
#
# **Expected Output:** AI suggests checking length or using safe access logic

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** fix the code by handling the runtime errors:
# ```
# numbers = [1, 2, 3]
# print(numbers[5])
# ```

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
numbers = [1, 2, 3]
try:
    print(numbers[5])
except IndexError:
    print("Error: The index is out of the list's range.")
# Out:
# Error: The index is out of the list's range.
