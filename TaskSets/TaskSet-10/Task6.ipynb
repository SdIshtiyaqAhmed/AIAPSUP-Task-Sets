# %% [markdown]
# **Description:** Use AI to simplify overly complex logic.
#
# Sample Input Code:
# ```
# def grade(score):
#     if score >= 90:
#         return "A"
#     else:
#         if score >= 80:
#             return "B"
#         else:
#             if score >= 70:
#                 return "C"
#             else:
#                 if score >= 60:
#                     return "D"
#                 else:
#                     return "F"
# ```
#
# **Expected Output:** Cleaner logic using elif or dictionary mapping.

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** simplify the logic in the function grade()

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"
