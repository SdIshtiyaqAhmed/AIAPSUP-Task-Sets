# %% [markdown]
# **Description:** Provide AI with this faulty code and ask it to improve error handling, naming, and readability.
#
# Python Script:
# ```
# def div(a,b):
#     return a/b
# print(div(10,0))
# ```
#
# **Expected Output:**
# * Function with proper error handling using try-except.
# * Better naming (divide_numbers).
# * AI-generated docstring explaining error handling.

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** improve the error handling, naming, and readability of the code

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def safe_divide(numerator, denominator):
    """Divides two numbers, handling ZeroDivisionError."""
    try:
        return numerator / denominator
    except ZeroDivisionError:
        return "Error: Cannot divide by zero."

print(safe_divide(10, 0))
print(safe_divide(10, 2))
# Out:
# Error: Cannot divide by zero.
# 5.0
