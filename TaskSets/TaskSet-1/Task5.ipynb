# %% [markdown]
# **Description:** Use Copilot to find the largest number in a list. Assess code quality and efficiency.
#
# **Expected Output:** A valid function with your review

# %% [markdown]
# **Prerequisites:** Latest version of VS Code is installed, GitHub Copilot in VS Code, Internet Connection
#
# **Prompt:** Function to find the largest number in a list

# %% [markdown]
# **Co-Pilot (AI) Generated Code:**

# %%
# Function to find the largest number in a list
def find_largest_number(numbers):
    if not numbers:
        return None  # Return None if the list is empty
    largest = numbers[0]
    for number in numbers:
        if number > largest:
            largest = number
    return largest
# Example usage
numbers = [3, 5, 2, 8, 1]
largest_number = find_largest_number(numbers)
print(f"The largest number in the list is: {largest_number}")
# Out:
# The largest number in the list is: 8

# %% [markdown]
# **Code review:** The AI generated code consists of a function named find_largest_number() to find the largest number in a list. The function also handles empty list condition and returns None. The function initializes the first number in the list as the “largest” (largest number), then iterate and compare each number in the list with “largest” if a number is greater than “largest” then assign that number to largest. After the iteration is completed, the function returns the “largest” (largest number).
