# %% [markdown]
# **Description:** Write a comment like # Function to reverse a string and use Copilot to generate the function.
#
# **Expected Output:** Auto-completed reverse function

# %% [markdown]
# **Prerequisites:** Latest version of VS Code is installed, GitHub Copilot in VS Code, Internet Connection
#
# **Prompt:** Function to reverse a string

# %% [markdown]
# **Co-Pilot (AI) Generated Code:**

# %%
# Function to reverse a string
def reverse_string(s):	
    return s[::-1]
# Example usage
input_string = "Hello, World!"
reversed_string = reverse_string(input_string)
print("Reversed String:", reversed_string)
# Output: !dlroW ,olleH
# Out:
# Reversed String: !dlroW ,olleH
