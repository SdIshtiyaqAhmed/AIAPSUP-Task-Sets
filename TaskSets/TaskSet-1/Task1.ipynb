# %% [markdown]
# **Description:** Install and configure GitHub Copilot in VS Code. Take screenshots of each step.
#
# **Expected Output:** Install and configure GitHub Copilot in VS Code. Take screenshots of each step.

# %% [markdown]
# **Prerequisites:** Latest version of VS Code is installed, GitHub Account, Internet Connection

# %% [markdown]
# Step 1: Open VS Code
#
# ![image.png](attachment:image.png)
#
# Step 2: Open the Extensions Tab
#
# ![image-2.png](attachment:image-2.png)
#
# Step 3: Search for “GitHub Copilot”
#
# ![image-3.png](attachment:image-3.png)
#
# Step 4: Click on “Install” and wait for VS Code to install the GitHub Copilot Extension
#
# ![image-4.png](attachment:image-4.png)
#
# Step 5: Close and Reopen VS Code
#
# ![image-5.png](attachment:image-5.png)
#
# Step 6:  Sign-in and Authorize GitHub Copilot using the GitHub account
#
# ![image-6.png](attachment:image-6.png)
#
# Step 7: GitHub Copilot is now Ready!
#
# ![image-7.png](attachment:image-7.png)
