# %% [markdown]
# **Description:** Use AI to complete a Student class with attributes and a method. Check output. Analyze the code generated by AI tool
#
# **Expected Output:** Class with constructor and display_details() method

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection

# %% [markdown]
# **Gemini (AI) Generated (Auto-completed) Code:**

# %%
class Student:
  def __init__(self, name, age, grade):
    self.name = name
    self.age = age
    self.grade = grade
  def display_details(self):
    print(f"Name: {self.name}, Age: {self.age}, Grade: {self.grade}")

student1 = Student("John", 15, "10th")
student1.display_details()

student2 = Student("Alice", 16, "11th")
student2.display_details()

student3 = Student("Bob", 17, "12th")
student3.display_details()
# Out:
# Name: John, Age: 15, Grade: 10th
# Name: Alice, Age: 16, Grade: 11th
# Name: Bob, Age: 17, Grade: 12th
