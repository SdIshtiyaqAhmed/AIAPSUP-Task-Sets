# %% [markdown]
# **Description:** Ask AI to write nested if-elif-else conditionals to classify age groups. Analyze the generated code. Ask AI to generate code using other conditional statements
#
# **Expected Output:** Age classification function with appropriate conditions and with explanation

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** write code to classify age groups using nested if-else-if conditions

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def classify_age(age):
  """Classifies age into different groups using nested if-else-if conditions."""
  if age < 0:
    return "Invalid age"
  else:
    if age < 13:
      return "Child"
    elif age < 20:
      return "Teenager"
    elif age < 60:
      return "Adult"
    else:
      return "Senior"

# Example usage
print(f"Age 5: {classify_age(5)}")
print(f"Age 15: {classify_age(15)}")
print(f"Age 30: {classify_age(30)}")
print(f"Age 70: {classify_age(70)}")
print(f"Age -10: {classify_age(-10)}")
# Out:
# Age 5: Child
# Age 15: Teenager
# Age 30: Adult
# Age 70: Senior
# Age -10: Invalid age

# %% [markdown]
# **Prompt:** write code to classify age groups using other conditional statements

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def classify_age_ifelse(age):
  """Classifies age into different groups using if-elif-else statements."""
  if age < 0:
    return "Invalid age"
  elif age < 13:
    return "Child"
  elif age < 20:
    return "Teenager"
  elif age < 60:
    return "Adult"
  else:
    return "Senior"

# Example usage
print(f"Age 5: {classify_age_ifelse(5)}")
print(f"Age 15: {classify_age_ifelse(15)}")
print(f"Age 30: {classify_age_ifelse(30)}")
print(f"Age 70: {classify_age_ifelse(70)}")
print(f"Age -10: {classify_age_ifelse(-10)}")
# Out:
# Age 5: Child
# Age 15: Teenager
# Age 30: Adult
# Age 70: Senior
# Age -10: Invalid age
