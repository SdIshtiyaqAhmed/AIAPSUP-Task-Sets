# %% [markdown]
# **Description:** One-shot: Give one input-output example to guide AI in writing a function that converts centimeters to inches.
#
# **Expected Output:** Function with correct conversion logic

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:**
# write a function that converts centimeters to inches.
#
# Example:
# Input: 3
# Output: 1.1811

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def cm_to_inches(cm):
  """
  Converts centimeters to inches.

  Args:
    cm: A number representing centimeters.

  Returns:
    The equivalent value in inches.
  """
  return cm * 0.393701

# Example usage:
print(cm_to_inches(3))
# Out:
# 1.181103
