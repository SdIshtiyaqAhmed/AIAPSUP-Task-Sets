# %% [markdown]
# **Description:** Provide this class with poor readability and ask AI to improve:
# * Naming conventions
# * Encapsulation
# * Readability & maintainability
#
# Python Script:
# ```
# class emp:
#     def __init__(self,n,s):
#         self.n=n
#         self.s=s
#     def inc(self,p):
#         self.s=self.s+(self.s*p/100)
#     def pr(self):
#         print("emp:",self.n,"salary:",self.s)
# ```
#
# **Expected Output:** Employee class with meaningful methods (increase_salary, display_info), formatted output, and added docstrings.

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** improve the naming convention, encapsulation, readability, and maintainability of the code

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def increase_salary(self, percentage):
        if percentage > 0:
            self.salary += (self.salary * percentage / 100)
        else:
            print("Percentage increase must be positive.")

    def display_employee_info(self):
        print(f"Employee: {self.name}, Salary: {self.salary}")
