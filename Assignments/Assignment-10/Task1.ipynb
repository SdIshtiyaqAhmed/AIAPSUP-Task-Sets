# %% [markdown]
# **Description:** Provide AI with the following nested conditional code and ask it to simplify and refactor for readability.
#
# Python script:
# ```
# def discount(price, category):
#     if category == "student":
#         if price > 1000:
#             return price * 0.9
#         else:
#             return price * 0.95
#     else:
#         if price > 2000:
#             return price * 0.85
#         else:
#             return price
# ```
#
# **Expected Output:** Refactored code using cleaner logic, possibly a dictionary or separate helper functions.

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** simplify and refactor the code

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def discount(price, category):
    discount_rate = 0.0

    if category == "student":
        discount_rate = 0.10 if price > 1000 else 0.05
    elif price > 2000:
        discount_rate = 0.15  # 15% discount for non-students over 2000

    return price * (1 - discount_rate)
