# %% [markdown]
# **Description:** Give AI this messy loop and ask it to refactor and optimize.
#
# Python script:
# ```
# def find_common(a, b):
#     res = []
#     for i in a:
#         for j in b:
#             if i == j:
#                 res.append(i)
#     return res
# ```
#
# **Expected Output:** Cleaner version using Python sets (set(a) & set(b))

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** refactor and optimize the code

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def find_common(a, b):
    # Convert one list to a set for efficient lookup
    set_b = set(b)
    res = []
    for item_a in a:
        if item_a in set_b:
            res.append(item_a)
    return res
