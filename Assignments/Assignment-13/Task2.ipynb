# %% [markdown]
# **Description:** Legacy function without proper error handling
#
# Python Code:
# ```
# def read_file(filename):
#     f = open(filename, "r")
#     data = f.read()
#     f.close()
#     return data
# ```
#
# **Expected Output:** AI refactors with with open() and try-except:

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** refactor this code:
# ```
# def read_file(filename):
#     f = open(filename, "r")
#     data = f.read()
#     f.close()
#     return data
# ```

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def read_file_refactored(filename):
    with open(filename, "r") as f:
        data = f.read()
    return data

# Example Usage:
# To demonstrate, let's create a dummy file first
with open("my_test_file.txt", "w") as f:
    f.write("Hello, this is a test file.\n")
    f.write("This is the second line.")

# Now, read the file using the refactored function
file_content = read_file_refactored("my_test_file.txt")
print(f"Content of 'my_test_file.txt':\n{file_content}")

# Clean up the dummy file
import os
os.remove("my_test_file.txt")
# Out:
# Content of 'my_test_file.txt':
# Hello, this is a test file.
# This is the second line.
