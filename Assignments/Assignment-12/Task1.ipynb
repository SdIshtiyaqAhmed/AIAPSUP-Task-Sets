# %% [markdown]
# **Description:** Write python code for linear_search () function to search a value in a list and extract its index.
#
# **Expected Output:** Python code for linear_search () function to search a value in a list and extract its index.

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** write python code for linear_search () function to search a value in a list and extract its index

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def linear_search(arr, target):
    """
    Performs a linear search to find the target value in the given list.

    Args:
        arr (list): The list to search through.
        target: The value to search for.

    Returns:
        int: The index of the target if found, otherwise -1.
    """
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

# Example usage:
my_list = [10, 25, 33, 47, 50, 68, 71]
search_value = 47

index = linear_search(my_list, search_value)

if index != -1:
    print(f"Value {search_value} found at index: {index}")
else:
    print(f"Value {search_value} not found in the list.")

search_value_not_found = 99
index_not_found = linear_search(my_list, search_value_not_found)

if index_not_found != -1:
    print(f"Value {search_value_not_found} found at index: {index_not_found}")
else:
    print(f"Value {search_value_not_found} not found in the list.")
# Out:
# Value 47 found at index: 3
# Value 99 not found in the list.
