# %% [markdown]
# **Description:** Debug a runtime error caused by division by zero. Let AI insert try-except.
# ```
# def divide(a,b):
#   return a/b
# ```
#
# **Expected Output:** Corrected function with safe error handling

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** fix the code by handling the runtime error using try-except:
# ```
# def divide(a,b):
#   return a/b
# ```

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def divide(a, b):
  try:
    return a / b
  except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
    return None
