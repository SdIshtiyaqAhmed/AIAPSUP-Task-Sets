# %% [markdown]
# **Description:** Paste a function with a missing colon (add(a, b)), and let AI fix the syntax error.
#
# ```
# def add(a, b)
#   return a + b
# ```
#
# **Expected Output:** Corrected function with syntax fix

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:**
# fix the code:
# ```
# def add(a, b)
#   return a + b
# ```

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def add(a, b):
  return a + b
