# %% [markdown]
# **Description:** Identify and fix a logic error in a loop that causes infinite iteration.
# ```
# def count_down(n):
#   while n >= 0:
#     print(n)
#     n += 1
# ```
#
# **Expected Output:** AI fixes increment/decrement error

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:**
# fix the code:
# ```
# def count_down(n):
#   while n >= 0:
#     print(n)
#     n += 1
# ```

# %% [markdown]
# **Gemini (AI) Generated Code:**

# %%
def count_down(n):
  while n >= 0:
    print(n)
    n -= 1

# Example usage:
count_down(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
