# %% [markdown]
# **Description:** Use AI to build a BankAccount class with deposit, withdraw, and balance methods. Analyze the generated code. Add comments and explain code
#
# **Expected Output:** Python code with explanation

# %% [markdown]
# **Prerequisites:** GitHub Copilot in VS Code / Gemini in Google Colab, Internet Connection
#
# **Prompt:** Implement a class named BankAccount with deposit, withdraw, and balance methods

# %% [markdown]
# **Gemini (AI) Generated Code (with manual documentation using comments):**

# %%
# implement the class named BankAccount
class BankAccount:
    
    # implement a constructor using __init__ and initialize the account_balance to 0 when a new BankAccount class instance is created
    def __init__(self):
        self.account_balance = 0
    
    # implement a function to deposit a certain amount into the bank account
    def deposit(self, amount):
        
        """
        args: amount (int) -> it is the amount to be deposited into the bank account
        """

        # add the amount to be deposited to the account balance
        self.account_balance += amount

    # implement a function to withdraw a certain amount into the bank account
    def withdraw(self, amount):
        
        """
        args: amount (int) -> it is the amount to be withdrawn from the bank account
        """

        # if the account balance is greater than or equal to the amount to be withdrawn
        if self.account_balance >= amount:

            # subtract the amount to be withdrawn from the account balance
            self.account_balance -= amount
        
        # if the account balance is less than the amount to be withdrawn
        else:

            # display / print insufficient funds 
            print("Insufficient funds.")

    # implement a function to check the account balance of the bank account
    def balance(self):

        # return the account balance of the bank account
        return self.account_balance
